# %%
import requests

    a =requests.get(f"https://jspmjscoe.edu.in/.html")
    with open(f"jsccescrap/page.html","w") as f:
        f.write(a.text)
        print(f"page loaded succecfully ohoo")
# Out:
#   Cell In[4], line 3
#     a =requests.get(f"https://jspmjscoe.edu.in/.html")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # Assistant
# The error occurs because there's unexpected indentation at the beginning of lines 3, 4, and 5. In Python, indentation is significant and used to define code blocks. Since these lines are not inside any block (like a function or loop), they should not be indented.
#
# Would you like me to provide the corrected code?

# %%
import requests

a = requests.get(f"https://www.amazon.in/gp/cart/view.html")
with open(f"jscoescrap/page.html","w",encoding=") as f:
    f.write(a.text)
    print(f"page loaded succecfully ohoo")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[8], line 5
#       3 a = requests.get(f"https://www.amazon.in/gp/cart/view.html")
#       4 with open(f"jscoescrap/page.html","w") as f:
# ----> 5     f.write(a.text)
#       6     print(f"page loaded succecfully ohoo")
#
# File ~\anaconda3\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u02d8' in position 48387: character maps to <undefined>

# %%
import requests

a = requests.get("https://www.amazon.in/gp/cart/view.html")
with open("jscoescrap/page.html", "w", encoding="utf-8") as f:
    f.write(a.text)
    print("page loaded successfully ohoo")
# Out:
# page loaded successfully ohoo
