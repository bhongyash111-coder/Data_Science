# %%
from bs4 import BeautifulSoup
import requests
with open(f"htmls/page.html","r") as f:
    content=f.read()

# %%
    soup = BeautifulSoup(content, "html.parser")

# %%
soup.h1
# Out:
# <h1>All products</h1>

# %%
soup.h1.text
# Out:
# 'All products'

# %%
soup.find("p")
# Out:
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>

# %%
soup.find_all("a")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 soup.find_all("a").text
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2885, in ResultSet.__getattr__(self, key)
#    2883 def __getattr__(self, key: str) -> None:
#    2884     """Raise a helpful exception to explain a common code fix."""
# -> 2885     raise AttributeError(
#    2886         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2887     )
#
# AttributeError: ResultSet object has no attribute "text". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.select_one("p.description")

# %%
soup.select("a")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 soup.select("a").text
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2885, in ResultSet.__getattr__(self, key)
#    2883 def __getattr__(self, key: str) -> None:
#    2884     """Raise a helpful exception to explain a common code fix."""
# -> 2885     raise AttributeError(
#    2886         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2887     )
#
# AttributeError: ResultSet object has no attribute "text". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
link = soup.find("a")
print(link["href"])
# Out:
# index.html

# %%
soup.p.parent
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
soup.select("a")
# Out:
# [<a href="index.html">Books to Scrape</a>,
#  <a href="index.html">Home</a>,
#  <a href="catalogue/category/books_1/index.html">
#
#                                  Books
#
#                          </a>,
#  <a href="catalogue/category/books/travel_2/index.html">
#
#                                  Travel
#
#                          </a>,
#  <a href="catalogue/category/books/mystery_3/index.html">
#
#                                  Mystery
#
#                          </a>,
#  <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                  Sequential Art
#
#                          </a>,
#  <a href="catalogue/category/books/classics_6/index.html">
#
#                                  Classics
#
#                          </a>,
# ...

# %%
items=[]
articles =soup.select("article.product_pod")
for article in articles :
    title=article.find("h3").find("a")["title"]
    price=article.select_one("p.price_colour").text
    print(price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 5
#       3 for article in articles :
#       4     title=article.find("h3").find("a")["title"]
# ----> 5     price=article.select_one("p.price_colour").text
#       6     print(price)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
title=article.find("a").find("h3")["title"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 title=article.find("a").find("h3")["title"]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
title=article.find("a").find("h3")["title"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 title=article.find("a").find("h3")["title"]
#
# TypeError: 'NoneType' object is not subscriptable
