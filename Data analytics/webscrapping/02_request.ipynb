# %%
import requests
for i in range(1,51):
    a=requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
    with open(f"htmls/page{i}.html","w",encoding="utf8") as f:
        f.write(a.text)
        print(f"page{i} loaded succecfully ohoo")
# Out:
# page1 loaded succecfully ohoo
# page2 loaded succecfully ohoo
# page3 loaded succecfully ohoo
# page4 loaded succecfully ohoo
# page5 loaded succecfully ohoo
# page6 loaded succecfully ohoo
# page7 loaded succecfully ohoo
# page8 loaded succecfully ohoo
# page9 loaded succecfully ohoo
# page10 loaded succecfully ohoo
# page11 loaded succecfully ohoo
# page12 loaded succecfully ohoo
# page13 loaded succecfully ohoo
# page14 loaded succecfully ohoo
# page15 loaded succecfully ohoo
# page16 loaded succecfully ohoo
# page17 loaded succecfully ohoo
# page18 loaded succecfully ohoo
# page19 loaded succecfully ohoo
# page20 loaded succecfully ohoo
# page21 loaded succecfully ohoo
# page22 loaded succecfully ohoo
# page23 loaded succecfully ohoo
# page24 loaded succecfully ohoo
# page25 loaded succecfully ohoo
# page26 loaded succecfully ohoo
# page27 loaded succecfully ohoo
# page28 loaded succecfully ohoo
# page29 loaded succecfully ohoo
# page30 loaded succecfully ohoo
# ...
